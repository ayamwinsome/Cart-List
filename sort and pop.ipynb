# %%
my_cart=[]
def add_list(item):
    my_cart.append(item)
def remove_list(item):
    my_cart.remove(item)
def sort_list(item):
    my_cart.sort()
def reverse_list(item):
    my_cart.reverse()
def pop_list(item):
    my_cart.pop()
def clear_list(item):
    my_cart.clear()
    
print("0. done")
print("1. book.........300")
print("2. pen.........50")
print("3. ruler.........50")
print("4. marker.........100")
print("5. biscuit .........150")
print("6. sweet.........150")
print("7. charger.........800")
print("8. cloth .........1500")
print("9. wristwatch.........700")
print("10. shoes.........1500")
print("11. bag .........1000")
print("12. mouse.........500")
print("13. sanitizer.........700")
print("14. soap.........200")
print("15. perfume.........700")
print("16. groundnut.........400")
print("17. pencil.........20")
print("18. chocolate.........200")
print("19. youghurt.........150")
print("20. remove book")
print("21. remove pen")
print("22. remove ruler")
print("23. remove marker")
print("24. remove biscuit")
print("25. remove sweet")
print("26. remove charger")
print("27. remove cloth")
print("28. remove wristwatch")
print("29. remove shoes")
print("30. remove bag")
print("31. remove mouse")
print("32. remove sanitizer")
print("33. remove soap")
print("34. remove perfume")
print("35. remove groundnut")
print("36. remove pencil")
print("37. remove chocolate")
print("38. remove youghurt")
print("39. sort my_cart")
print("40. reverse my_cart")
print("41. pop my_cart")
print("42. clear my_cart")
print("Enter the items you need")
item=input()
sum=0
while (item!="42"):
    if(item=="1"):
        add_list("book")
        sum +=300
        print(my_cart)
        print("enter more items or 0 to exit")
        item=input()
    elif(item=="2"):
        add_list("pen")
        sum +=50
        print(my_cart)
        print("enter more items or 0 to exit")
        item=input()
    elif(item=="3"):
        add_list("ruler")
        sum +=50
        print(my_cart)
        print("enter more items or 0 to exit")
        item=input()
    elif(item=="4"):
        add_list("marker")
        sum +=100
        print(my_cart)
        print("enter more items or 0 to exit")
        item=input()
    elif(item=="5"):
        add_list("Biscut")
        sum +=150
        print(my_cart)
        print("enter more items or 0 to exit")
        item=input()
    elif(item=="6"):
        add_list("sweet")
        sum +=150
        print(my_cart)
        print("enter more items or 0 to exit")
        item=input()
    elif(item=="7"):
        add_list("charger")
        sum +=800
        print(my_cart)
        print("enter more items or 0 to exit")
        item=input()
    elif(item=="8"):
        add_list("cloth")
        sum +=1500
        print(my_cart)
        print("enter more items or 0 to exit")
        item=input()
    elif(item=="9"):
        add_list("wristwatch")
        sum +=700
        print(my_cart)
        print("enter more items or 0 to exit")
        item=input()
    elif(item=="10"):
        add_list("shoes")
        sum +=1500
        print(my_cart)
        print("enter more items or 0 to exit")
        item=input()
    elif(item=="11"):
        add_list("bag")
        sum +=1000
        print(my_cart)
        print("enter more items or 0 to exit")
        item=input()
    elif(item=="12"):
        add_list("mouse")
        sum +=500
        print(my_cart)
        print("enter more items or 0 to exit")
        item=input()
    elif(item=="13"):
        add_list("sanitizer")
        sum +=700
        print(my_cart)
        print("enter more items or 0 to exit")
        item=input()
    elif(item=="14"):
        add_list("soap")
        sum +=200
        print(my_cart)
        print("enter more items or 0 to exit")
        item=input()
    elif(item=="15"):
        add_list("perfume")
        sum +=700
        print(my_cart)
        print("enter more items or 0 to exit")
        item=input()
    elif(item=="16"):
        add_list("groundnut")
        sum +=400
        print(my_cart)
        print("enter more items or 0 to exit")
        item=input()
    elif(item=="17"):
        add_list("pencil")
        sum +=20
        print(my_cart)
        print("enter more items or 0 to exit")
        item=input()
    elif(item=="18"):
        add_list("chocolate")
        sum +=200
        print(my_cart)
        print("enter more items or 0 to exit")
        item=input()
    elif(item=="19"):
        add_list("youghurt")
        sum +=150
        print(my_cart)
        print("enter more items or 0 to exit")
        item=input()
    elif(item=="20"):
        check_list = len(my_cart)
        if(check_list == 43):
            print("Sorry but your cart is empty, make a selection")
            item = input()
        else:
            remove_list("book")
            sum -=300
            print(my_cart)
            print("enter more items or 0 to exit")
            item=input()
    elif(item=="21"):
        check_list = len(my_cart)
        if(check_list == 43):
            print("Sorry but your cart is empty, make a selection")
            item = input()
        else:
            remove_list("pen")
            sum -=50
            print(my_cart)
            print("enter more items or 0 to exit")
            item=input()
    elif(item=="22"):
        check_list = len(my_cart)
        if(check_list == 43):
            print("Sorry but your cart is empty, make a selection")
            item = input()
        else:
            remove_list("ruler")
            sum -=50
            print(my_cart)
            print("enter more items or 0 to exit")
            item=input()
    elif(item=="23"):
        check_list = len(my_cart)
        if(check_list == 43):
            print("Sorry but your cart is empty, make a selection")
            item = input()
        else:
            remove_list("marker")
            sum -=100
            print(my_cart)
            print("enter more items or 0 to exit")
            item=input()
    elif(item=="24"):
        check_list = len(my_cart)
        if(check_list == 43):
            print("Sorry but your cart is empty, make a selection")
            item = input()
        else:
            remove_list("biscuit")
            sum -=150
            print(my_cart)
            print("enter more items or 0 to exit")
            item=input()
    elif(item=="25"):
        check_list = len(my_cart)
        if(check_list == 43):
            print("Sorry but your cart is empty, make a selection")
            item = input()
        else:
            remove_list("sweet")
            sum -=150
            print(my_cart)
            print("enter more items or 0 to exit")
            item=input()
    elif(item=="26"):
        check_list = len(my_cart)
        if(check_list == 43):
            print("Sorry but your cart is empty, make a selection")
            item = input()
        else:
            remove_list("charger")
            sum -=800
            print(my_cart)
            print("enter more items or 0 to exit")
            item=input()
    elif(item=="27"):
        check_list = len(my_cart)
        if(check_list == 43):
            print("Sorry but your cart is empty, make a selection")
            item = input()
        else:
            remove_list("cloth")
            sum -=1500
            print(my_cart)
            print("enter more items or 0 to exit")
            item=input()
    elif(item=="28"):
        check_list = len(my_cart)
        if(check_list == 43):
            print("Sorry but your cart is empty, make a selection")
            item = input()
        else:
            remove_list("wristwatch")
            sum -=700
            print(my_cart)
            print("enter more items or 0 to exit")
            item=input()
    elif(item=="29"):
        check_list = len(my_cart)
        if(check_list == 43):
            print("Sorry but your cart is empty, make a selection")
            item = input()
        else:
            remove_list("shoes")
            sum -=1500
            print(my_cart)
            print("enter more items or 0 to exit")
            item=input()
    elif(item=="30"):
        check_list = len(my_cart)
        if(check_list == 43):
            print("Sorry but your cart is empty, make a selection")
            item = input()
        else:
            remove_list("bag")
            sum -=1000
            print(my_cart)
            print("enter more items or 0 to exit")
            item=input()
    elif(item=="31"):
        check_list = len(my_cart)
        if(check_list == 43):
            print("Sorry but your cart is empty, make a selection")
            item = input()
        else:
            remove_list("mouse")
            sum -=500
            print(my_cart)
            print("enter more items or 0 to exit")
            item=input()
    elif(item=="32"):
        check_list = len(my_cart)
        if(check_list == 43):
            print("Sorry but your cart is empty, make a selection")
            item = input()
        else:
            remove_list("sanitizer")
            sum -=700
            print(my_cart)
            print("enter more items or 0 to exit")
            item=input()
    elif(item=="33"):
        check_list = len(my_cart)
        if(check_list == 43):
            print("Sorry but your cart is empty, make a selection")
            item = input()
        else:
            remove_list("soap")
            sum -=200
            print(my_cart)
            print("enter more items or 0 to exit")
            item=input()
    elif(item=="34"):
        check_list = len(my_cart)
        if(check_list == 43):
            print("Sorry but your cart is empty, make a selection")
            item = input()
        else:
            remove_list("perfume")
            sum -=700
            print(my_cart)
            print("enter more items or 0 to exit")
            item=input()
    elif(item=="35"):
        check_list = len(my_cart)
        if(check_list == 43):
            print("Sorry but your cart is empty, make a selection")
            item = input()
        else:
            remove_list("groundnut")
            sum -=400
            print(my_cart)
            print("enter more items or 0 to exit")
            item=input()
    elif(item=="36"):
        check_list = len(my_cart)
        if(check_list == 43):
            print("Sorry but your cart is empty, make a selection")
            item = input()
        else:
            remove_list("pencil")
            sum -=700
            print(my_cart)
            print("enter more items or 0 to exit")
            item=input()
    elif(item=="37"):
        check_list = len(my_cart)
        if(check_list == 43):
            print("Sorry but your cart is empty, make a selection")
            item = input()
        else:
            remove_list("chocolate")
            sum -=200
            print(my_cart)
            print("enter more items or 0 to exit")
            item=input()
    elif(item=="38"):
        check_list = len(my_cart)
        if(check_list == 43):
            print("Sorry but your cart is empty, make a selection")
            item = input()
        else:
            remove_list("youghurt")
            sum -=150
            print(my_cart)
            print("enter more items or 0 to exit")
            item=input()
    elif(item=="39"):
        sort_list(item)
        sum=0
        print(my_cart)
        print("item sort or 0 to exit")
        item=input()
    elif(item=="40"):
        reverse_list(item)
        sum=0
        print(my_cart)
        print("item reversed or 0 to exit")
        item=input()
    elif(item=="41"):
        pop_list(item)
        sum=0
        print(my_cart)
        print("item poped or 0 to exit")
        item=input()
    elif(item=="42"):
        clear_list("item")
        sum =0
        print(my_cart)
        print("item cleared or 0 to exit")
        item=input()
    else:
        print("invalid input, please enter a valid input")
        item = input()
print(f"your items are :{my_cart}")
my_cart.sort()
print(f"your bill is : {sum}")
print("Thanks for your patronage")
print("we look forward to seeing you")
